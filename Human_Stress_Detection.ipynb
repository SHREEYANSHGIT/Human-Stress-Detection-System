# %% [markdown]
# **importing liberaries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout
from tensorflow.keras.layers import ReLU,LeakyReLU

# %%
# Loading dataset
dataset = pd.read_csv('extended_stress_detection_data.csv')

# %%
dataset.shape
# Out:
# (3000, 22)

# %%
dataset.head()
# Out:
#     Age  Gender         Occupation Marital_Status  Sleep_Duration  \
# 0  30.0    Male  Software Engineer         Single             7.0
# 1  35.0  Female  Marketing Manager        Married             6.0
# 2  40.0    Male     Data Scientist       Divorced             7.0
# 3  35.0    Male  Software Engineer         Single             7.0
# 4  29.0  Female            Teacher         Single             8.0
#
#    Sleep_Quality Wake_Up_Time  Bed_Time  Physical_Activity  Screen_Time  ...  \
# 0            4.0      7:00 AM  10:00 PM                2.0          4.0  ...
# 1            3.0      6:00 AM  11:00 PM                1.0          3.0  ...
# 2            4.0      7:00 AM  10:00 PM                2.0          4.0  ...
# 3            4.0      7:00 AM  10:00 PM                2.0          4.0  ...
# 4            5.0      6:30 AM  10:30 PM                3.0          2.0  ...
#
#    Smoking_Habit  Work_Hours Travel_Time  Social_Interactions  \
# 0             No         8.0         1.0                  5.0
# 1             No         9.0         2.0                  3.0
# 2             No         8.0         1.0                  5.0
# 3             No         8.0         1.0                  5.0
# 4             No         7.0         1.0                  4.0
#
#    Meditation_Practice      Exercise_Type Blood_Pressure Cholesterol_Level  \
# 0                  Yes             Cardio          120.0             180.0
# 1                   No               Yoga          110.0             160.0
# 2                  Yes  Strength Training          130.0             200.0
# 3                  Yes             Cardio          120.0             180.0
# 4                  Yes               Yoga          110.0             180.0
#
#    Blood_Sugar_Level  Stress_Detection
# 0               90.0               Low
# 1               80.0            Medium
# 2              100.0              High
# 3               90.0               Low
# 4               90.0               Low
#
# [5 rows x 22 columns]

# %%
## divide the data into independent and dependent features

x = dataset.iloc[:, 0:21]   # from column index 0 to 20 (21 columns excluding the last one)
y = dataset.iloc[:, 21]     # column at index 21 (the last column, 'Stress_Detection')

# %%
x.head()
# Out:
#     Age  Gender         Occupation Marital_Status  Sleep_Duration  \
# 0  30.0    Male  Software Engineer         Single             7.0
# 1  35.0  Female  Marketing Manager        Married             6.0
# 2  40.0    Male     Data Scientist       Divorced             7.0
# 3  35.0    Male  Software Engineer         Single             7.0
# 4  29.0  Female            Teacher         Single             8.0
#
#    Sleep_Quality Wake_Up_Time  Bed_Time  Physical_Activity  Screen_Time  ...  \
# 0            4.0      7:00 AM  10:00 PM                2.0          4.0  ...
# 1            3.0      6:00 AM  11:00 PM                1.0          3.0  ...
# 2            4.0      7:00 AM  10:00 PM                2.0          4.0  ...
# 3            4.0      7:00 AM  10:00 PM                2.0          4.0  ...
# 4            5.0      6:30 AM  10:30 PM                3.0          2.0  ...
#
#    Alcohol_Intake  Smoking_Habit Work_Hours  Travel_Time  Social_Interactions  \
# 0               0             No        8.0          1.0                  5.0
# 1               1             No        9.0          2.0                  3.0
# 2               0             No        8.0          1.0                  5.0
# 3               0             No        8.0          1.0                  5.0
# 4               0             No        7.0          1.0                  4.0
#
#    Meditation_Practice      Exercise_Type Blood_Pressure  Cholesterol_Level  \
# 0                  Yes             Cardio          120.0              180.0
# 1                   No               Yoga          110.0              160.0
# 2                  Yes  Strength Training          130.0              200.0
# 3                  Yes             Cardio          120.0              180.0
# 4                  Yes               Yoga          110.0              180.0
#
#    Blood_Sugar_Level
# 0               90.0
# 1               80.0
# 2              100.0
# 3               90.0
# 4               90.0
#
# [5 rows x 21 columns]

# %%
y.head()
# Out:
# 0       Low
# 1    Medium
# 2      High
# 3       Low
# 4       Low
# Name: Stress_Detection, dtype: object

# %%
if 'Occupation' in x.columns:
    x = x.drop('Occupation', axis=1)
if 'Exercise_Type' in x.columns:
    x = x.drop('Exercise_Type', axis=1)

# %%
x.head()
# Out:
#     Age  Gender Marital_Status  Sleep_Duration  Sleep_Quality Wake_Up_Time  \
# 0  30.0    Male         Single             7.0            4.0      7:00 AM
# 1  35.0  Female        Married             6.0            3.0      6:00 AM
# 2  40.0    Male       Divorced             7.0            4.0      7:00 AM
# 3  35.0    Male         Single             7.0            4.0      7:00 AM
# 4  29.0  Female         Single             8.0            5.0      6:30 AM
#
#    Bed_Time  Physical_Activity  Screen_Time  Caffeine_Intake  Alcohol_Intake  \
# 0  10:00 PM                2.0          4.0                1               0
# 1  11:00 PM                1.0          3.0                0               1
# 2  10:00 PM                2.0          4.0                1               0
# 3  10:00 PM                2.0          4.0                1               0
# 4  10:30 PM                3.0          2.0                1               0
#
#   Smoking_Habit  Work_Hours  Travel_Time  Social_Interactions  \
# 0            No         8.0          1.0                  5.0
# 1            No         9.0          2.0                  3.0
# 2            No         8.0          1.0                  5.0
# 3            No         8.0          1.0                  5.0
# 4            No         7.0          1.0                  4.0
#
#   Meditation_Practice  Blood_Pressure  Cholesterol_Level  Blood_Sugar_Level
# 0                 Yes           120.0              180.0               90.0
# 1                  No           110.0              160.0               80.0
# 2                 Yes           130.0              200.0              100.0
# 3                 Yes           120.0              180.0               90.0
# 4                 Yes           110.0              180.0               90.0

# %%
# replacing yes no with 1 , 0

x['Smoking_Habit'] = x['Smoking_Habit'].replace({'Yes': 1, 'No': 0})
x['Meditation_Practice'] = x['Meditation_Practice'].replace({'Yes': 1, 'No': 0})
# Out:
# C:\Users\shreeyansh\AppData\Local\Temp\ipykernel_30224\2133179599.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   x['Smoking_Habit'] = x['Smoking_Habit'].replace({'Yes': 1, 'No': 0})
# C:\Users\shreeyansh\AppData\Local\Temp\ipykernel_30224\2133179599.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   x['Meditation_Practice'] = x['Meditation_Practice'].replace({'Yes': 1, 'No': 0})

# %%
## Feature engineering
## dummies >> one hot encoding

Gender = pd.get_dummies(x['Gender'],drop_first=True).astype(int)
Marital_Status = pd.get_dummies(x['Marital_Status'],drop_first=True).astype(int)

# %%
Marital_Status
# Out:
#       Married  Single
# 0           0       1
# 1           1       0
# 2           0       0
# 3           0       1
# 4           0       1
# ...       ...     ...
# 2995        0       1
# 2996        0       1
# 2997        0       1
# 2998        0       0
# 2999        1       0
#
# [3000 rows x 2 columns]

# %%
# deleting from org x dataset

if 'Marital_Status' in x.columns:
    x = x.drop('Marital_Status', axis=1)
if 'Gender' in x.columns:
    x = x.drop('Gender', axis=1)

# %%
# adding inside x dataset
x=pd.concat([x,Gender,Marital_Status],axis=1)

# %%
import pandas as pd

# Ensure 'Wake_Up_Time' and 'Bed_Time' columns exist before processing
if 'Wake_Up_Time' in x.columns and 'Bed_Time' in x.columns:
    # Convert AM/PM to datetime objects
    x['Wake_Up_Time'] = pd.to_datetime(x['Wake_Up_Time'])
    x['Bed_Time'] = pd.to_datetime(x['Bed_Time'])

    # Extract hour as a number (0-23)
    x['Wake_Up_Time_Hour'] = x['Wake_Up_Time'].dt.hour
    x['Bed_Time_Hour'] = x['Bed_Time'].dt.hour

    # Drop the original string columns after conversion
    x = x.drop(['Wake_Up_Time', 'Bed_Time'], axis=1)
    print("Successfully converted and dropped 'Wake_Up_Time' and 'Bed_Time' columns.")
else:
    print("Warning: 'Wake_Up_Time' or 'Bed_Time' column not found in x. Skipping conversion and dropping. Make sure this cell is executed before train_test_split if these columns are expected.")
# Out:
# Successfully converted and dropped 'Wake_Up_Time' and 'Bed_Time' columns.
# C:\Users\shreeyansh\AppData\Local\Temp\ipykernel_30224\63988185.py:6: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   x['Wake_Up_Time'] = pd.to_datetime(x['Wake_Up_Time'])
# C:\Users\shreeyansh\AppData\Local\Temp\ipykernel_30224\63988185.py:7: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   x['Bed_Time'] = pd.to_datetime(x['Bed_Time'])

# %%
x.head()
# Out:
#     Age  Sleep_Duration  Sleep_Quality  Physical_Activity  Screen_Time  \
# 0  30.0             7.0            4.0                2.0          4.0
# 1  35.0             6.0            3.0                1.0          3.0
# 2  40.0             7.0            4.0                2.0          4.0
# 3  35.0             7.0            4.0                2.0          4.0
# 4  29.0             8.0            5.0                3.0          2.0
#
#    Caffeine_Intake  Alcohol_Intake  Smoking_Habit  Work_Hours  Travel_Time  \
# 0                1               0              0         8.0          1.0
# 1                0               1              0         9.0          2.0
# 2                1               0              0         8.0          1.0
# 3                1               0              0         8.0          1.0
# 4                1               0              0         7.0          1.0
#
#    Social_Interactions  Meditation_Practice  Blood_Pressure  \
# 0                  5.0                    1           120.0
# 1                  3.0                    0           110.0
# 2                  5.0                    1           130.0
# 3                  5.0                    1           120.0
# 4                  4.0                    1           110.0
#
#    Cholesterol_Level  Blood_Sugar_Level  Male  Married  Single  \
# 0              180.0               90.0     1        0       1
# 1              160.0               80.0     0        1       0
# 2              200.0              100.0     1        0       0
# 3              180.0               90.0     1        0       1
# 4              180.0               90.0     0        0       1
#
#    Wake_Up_Time_Hour  Bed_Time_Hour
# 0                  7             22
# 1                  6             23
# 2                  7             22
# 3                  7             22
# 4                  6             22

# %%
y.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    0
# 4    0
# Name: Stress_Detection, dtype: int64

# %%
# replacing the values to 1 , 0
y = y.replace({'High': 1, 'Medium': 1, 'Low': 0})
# Out:
# C:\Users\shreeyansh\AppData\Local\Temp\ipykernel_30224\678311703.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   y = y.replace({'High': 1, 'Medium': 1, 'Low': 0})

# %%
## Splitting the dataset into traning set and test set

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
## Feature Scaling

model =  StandardScaler()
x_train = model.fit_transform(x_train) # ✅ Learns + applies scaling

x_test = model.transform(x_test)  # ✅ Only applies same scaling ,to avoid data leakage

# %%
y_train
# Out:
# 642     0
# 700     1
# 226     1
# 1697    0
# 1010    1
#        ..
# 1638    1
# 1095    0
# 1130    1
# 1294    1
# 860     1
# Name: Stress_Detection, Length: 2400, dtype: int64

# %%
x_test.shape
# Out:
# (600, 20)

# %%
x_train.shape
# Out:
# (2400, 20)

# %%
x_test
# Out:
# array([[-0.99893247,  0.54886205,  0.44926858, ...,  1.09812675,
#          1.18130694, -0.44301038],
#        [ 0.38874498,  2.03171304, -0.5528551 , ..., -0.91064169,
#          0.24777495,  0.73747619],
#        [ 0.93775968, -0.63209113, -0.59334495, ...,  1.09812675,
#          0.24777495, -0.24626261],
#        ...,
#        [-0.90413857, -0.20588246,  0.12534981, ...,  1.09812675,
#          1.18130694, -0.44301038],
#        [-1.27278153,  1.3480033 ,  1.67408641, ...,  1.09812675,
#          0.24777495, -0.44301038],
#        [-0.45913384,  1.14377832, -1.4436317 , ...,  1.09812675,
#         -0.68575704,  0.34398067]])

# %%
x_train
# Out:
# array([[ 1.59736728, -0.11708899,  0.22657443, ..., -0.91064169,
#          2.11483893, -0.24626261],
#        [-0.11418935, -0.20588246, -0.07709941, ..., -0.91064169,
#          0.24777495, -0.04951485],
#        [ 1.46570907, -0.29467594, -0.88689633, ..., -0.91064169,
#          0.24777495,  0.54072843],
#        ...,
#        [-0.8501587 ,  1.65878046, -2.42551046, ..., -0.91064169,
#          0.24777495,  0.54072843],
#        [-0.70270152,  1.49007286, -1.69669324, ...,  1.09812675,
#         -2.55282102,  0.34398067],
#        [ 0.97462398,  1.09938158,  0.37841135, ..., -0.91064169,
#          1.18130694, -0.44301038]])

# %%
## now lets create the ANN
classifier = Sequential()

# %%
## adding the input layer
classifier.add(Dense(units=64,activation='relu'))

# %%
## adding first hidden layer
classifier.add(Dense(units=128,activation='relu'))

# %%
## adding first hidden layer
classifier.add(Dense(units=128,activation='relu'))
classifier.add(Dropout(0.1))

# %%
## adding output layer
classifier.add(Dense(units=1,activation='sigmoid'))

# %%
##  Early stoping
import tensorflow as tf
from tensorflow import keras
Early_stoping= keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0.0001,
    patience=20,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
    
)

# %%
classifier.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model_history = classifier.fit(x_train,y_train,validation_split=0.33,batch_size=5,epochs=100,callbacks=Early_stoping)
# Out:
# Epoch 1/100
# 322/322 [==============================] - 2s 5ms/step - loss: 0.4305 - accuracy: 0.8114 - val_loss: 0.3956 - val_accuracy: 0.8285
# Epoch 2/100
# 322/322 [==============================] - 1s 4ms/step - loss: 0.3598 - accuracy: 0.8438 - val_loss: 0.3928 - val_accuracy: 0.8386
# Epoch 3/100
# 322/322 [==============================] - 1s 4ms/step - loss: 0.3125 - accuracy: 0.8693 - val_loss: 0.3768 - val_accuracy: 0.8462
# Epoch 4/100
# 322/322 [==============================] - 1s 4ms/step - loss: 0.2679 - accuracy: 0.8899 - val_loss: 0.3809 - val_accuracy: 0.8361
# Epoch 5/100
# 322/322 [==============================] - 2s 5ms/step - loss: 0.2242 - accuracy: 0.9123 - val_loss: 0.3489 - val_accuracy: 0.8651
# Epoch 6/100
# 322/322 [==============================] - 1s 4ms/step - loss: 0.1922 - accuracy: 0.9291 - val_loss: 0.3277 - val_accuracy: 0.8638
# Epoch 7/100
# 322/322 [==============================] - 1s 4ms/step - loss: 0.1625 - accuracy: 0.9390 - val_loss: 0.3615 - val_accuracy: 0.8613
# Epoch 8/100
# 322/322 [==============================] - 1s 4ms/step - loss: 0.1410 - accuracy: 0.9409 - val_loss: 0.4200 - val_accuracy: 0.8752
# Epoch 9/100
# 322/322 [==============================] - 1s 4ms/step - loss: 0.1182 - accuracy: 0.9546 - val_loss: 0.3575 - val_accuracy: 0.8802
# Epoch 10/100
# 322/322 [==============================] - 1s 4ms/step - loss: 0.1026 - accuracy: 0.9558 - val_loss: 0.4684 - val_accuracy: 0.8663
# Epoch 11/100
# 322/322 [==============================] - 1s 4ms/step - loss: 0.0932 - accuracy: 0.9614 - val_loss: 0.3995 - val_accuracy: 0.8701
# Epoch 12/100
# 322/322 [==============================] - 1s 4ms/step - loss: 0.0724 - accuracy: 0.9695 - val_loss: 0.4180 - val_accuracy: 0.8815
# Epoch 13/100
# 322/322 [==============================] - 1s 4ms/step - loss: 0.0924 - accuracy: 0.9639 - val_loss: 0.4350 - val_accuracy: 0.8928
# Epoch 14/100
# 322/322 [==============================] - 1s 4ms/step - loss: 0.0677 - accuracy: 0.9726 - val_loss: 0.4236 - val_accuracy: 0.8802
# Epoch 15/100
# 322/322 [==============================] - 1s 4ms/step - loss: 0.0534 - accuracy: 0.9770 - val_loss: 0.4245 - val_accuracy: 0.8802
# Epoch 16/100
# 322/322 [==============================] - 1s 4ms/step - loss: 0.0634 - accuracy: 0.9726 - val_loss: 0.4317 - val_accuracy: 0.8789
# Epoch 17/100
# 322/322 [==============================] - 1s 4ms/step - loss: 0.0566 - accuracy: 0.9757 - val_loss: 0.4530 - val_accuracy: 0.8928
# Epoch 18/100
# 322/322 [==============================] - 1s 4ms/step - loss: 0.0366 - accuracy: 0.9863 - val_loss: 0.6625 - val_accuracy: 0.8789
# Epoch 19/100
# 322/322 [==============================] - 1s 4ms/step - loss: 0.0401 - accuracy: 0.9838 - val_loss: 0.5524 - val_accuracy: 0.8663
# Epoch 20/100
# 322/322 [==============================] - 1s 4ms/step - loss: 0.0364 - accuracy: 0.9832 - val_loss: 0.4959 - val_accuracy: 0.8815
# Epoch 21/100
# 322/322 [==============================] - 1s 4ms/step - loss: 0.0364 - accuracy: 0.9844 - val_loss: 0.5449 - val_accuracy: 0.8840
# Epoch 22/100
# 322/322 [==============================] - 1s 4ms/step - loss: 0.0405 - accuracy: 0.9863 - val_loss: 0.5925 - val_accuracy: 0.8789
# Epoch 23/100
# 322/322 [==============================] - 1s 4ms/step - loss: 0.0314 - accuracy: 0.9857 - val_loss: 0.6744 - val_accuracy: 0.8991
# Epoch 24/100
# 322/322 [==============================] - 1s 4ms/step - loss: 0.0366 - accuracy: 0.9851 - val_loss: 0.5620 - val_accuracy: 0.8840
# Epoch 25/100
# 322/322 [==============================] - 1s 4ms/step - loss: 0.0438 - accuracy: 0.9869 - val_loss: 0.5940 - val_accuracy: 0.8865
# Epoch 26/100
# 322/322 [==============================] - 2s 5ms/step - loss: 0.0269 - accuracy: 0.9913 - val_loss: 0.6512 - val_accuracy: 0.8827
# Epoch 26: early stopping

# %%
# history keys
model_history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
## summary of history for accuracy
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','test'],loc='upper left')
plt.show()

# %%
## summary of history for loss
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','test'],loc='upper left')
plt.show()

# %%
# making the prediction and evaluating model
y_pred = classifier.predict(x_test)
y_pred = (y_pred>=0.5)
# Out:
# 19/19 [==============================] - 0s 1ms/step

# %%
## making the confusion  matrix
cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[ 59,  58],
#        [ 22, 461]], dtype=int64)

# %%
## the accurarcy

score = accuracy_score(y_pred,y_test)
print(score)
# Out:
# 0.8666666666666667

# %%
classifier.save("stress_model.h5")

# %%
import pickle
# Dumping the scaler (named 'model' in your notebook)
pickle.dump(model, open("scaler.pkl", "wb"))
print("Scaler dumped successfully!")
# Out:
# Scaler dumped successfully!
